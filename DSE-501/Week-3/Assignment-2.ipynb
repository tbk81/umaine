# %% [markdown]
# ### Import Statments

# %%
import pandas as pd
df = pd.read_excel("DSE 501 Yahtzee Assignment.xlsx")
df.head()
# Out:
#    Die1  Die2  Die3  Die4  Die5
# 0     4     6     1     1     3
# 1     5     5     3     1     2
# 2     1     4     6     1     6
# 3     5     6     4     1     3
# 4     6     4     4     6     6
